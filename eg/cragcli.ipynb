# %%
my &f1 = llm-function({"What is the $^a of $^b in $^c. Give numerical answer only."})
# Out:
# LLM::Function(-> **@args, *%args { #`(Block|2534300604120) ... }, 'chatgpt')

# %%
&f1('GDP', 'California, USA', '2020')
# Out:
# 3134000000000

# %%
#% openai
what is algolia (one para)
# Out:
# Algolia is a search-as-a-service platform that provides developers with the tools they need to create fast, relevant, and personalized search experiences for their websites and applications. By offering powerful search capabilities, instant indexing, and robust analytics, Algolia helps companies improve user engagement, increase conversions, and drive revenue growth through optimized search functionality.

# %% [markdown]
# # Transform .cast Files
#
# Paste in a .cast file and try to adjust it in a Chat session
